# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import seaborn as sns

# %%
data = pd.read_csv("/media/arv/HP USB20FD/AI_DATA/Breast_Cancer_Data.csv")
data.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data.isna().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
data.info()

# %%
data.describe()

# %%
correlation = data.corr()
fig = plt.figure(figsize=(12,15))
a = sns.heatmap(correlation,cmap="Blues")
a.set_title("Data Correlation")
# Out:
# Text(0.5, 1.0, 'Data Correlation')

# %%
y = data['diagnosis'].values
X = data.drop(['diagnosis'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
svc = SVC(C=10, kernel = 'linear')
svc.fit(X_train, y_train)
# Out:
# SVC(C=10, kernel='linear')

# %%
predict = svc.predict(X_test)
acc = accuracy_score(y_test, predict)
print("Acc Score: ",round(acc*100,2))
# Out:
# Acc Score:  89.47

# %%
svc = SVC(C=10,kernel = 'rbf', gamma = 2)
svc.fit(X_train, y_train)
predict = svc.predict(X_test)
acc = accuracy_score(y_test, predict)
print("Acc Score: ",round(acc*100,2))
# Out:
# Acc Score:  63.16
